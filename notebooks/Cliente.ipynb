# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Carregar os dados
data = pd.read_csv('..\datasets\Mall_Customers.csv')

# Selecionar as características relevantes para clustering
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9504\2262146277.py:7: SyntaxWarning: invalid escape sequence '\d'
#   data = pd.read_csv('..\datasets\Mall_Customers.csv')

# %%
# Padronizar as características
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Instanciar o modelo K-means com 5 clusters
kmeans = KMeans(n_clusters=5, random_state=42)

# Ajustar o modelo aos dados
kmeans.fit(X_scaled)

# Obter os rótulos de cluster para cada ponto de dado
labels = kmeans.labels_

# Adicionar os rótulos de cluster aos dados
data['Cluster'] = labels

# %%
# Plotar os clusters
plt.figure(figsize=(8, 6))

colors = ['red', 'blue', 'green', 'purple', 'orange']
for i in range(5):
    cluster_data = data[data['Cluster'] == i]
    plt.scatter(cluster_data['Annual Income (k$)'], cluster_data['Spending Score (1-100)'], c=colors[i], label=f'Cluster {i}')

plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Clustering de Clientes')
plt.legend()
plt.show()
